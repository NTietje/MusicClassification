# %% [markdown]
# Erstellung der CNN-Darstellungen zu den Trainingsiterationen.
# Bei jedem Codeblock verweist der Titel auf den untersuchten Bereich.

# %%
from ipynb.fs.full.history_nb import *
from ipynb.fs.full.plot import *

# %% [markdown]
# Die ersten Bezeichnungen, die in der Ausgabe erscheinen wie "cnn_drop_0_3_24_19.json", sind die besten Trainingsdurchläufe einer Variante.

# %%
''' 
############### CNN Dropout ################

'''
# define 
folder = 'mirror_cnn_params'
template_path = folder + '/drop/0_1/cnn_drop_0_1_0'

# folders of histories
subfolders = ['drop/0_1','drop/0_2_24','drop/0_3_24','4_300_001_r1'] #'4_300_00025_r1','4_300_0001_r1'

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path, epoch_limit=80) #, epoch_limit=80

# graph settings  
labels = ['0_1','0_2_24','0_3_24','none']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.9, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.65, 0.8])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.5, 1.01],  metric2='accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.2, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, window=[0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, window=[0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, window=[0, 0.8])
evaluate_bar_plot(avgs, labels, 'accuracy', window=[0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, window=[0, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors)
bar_plot(
    avgs, labels,'Average of 30 Trainings', 'max','traintime', colors)
# Out:
# cnn_drop_0_1_0.json
# cnn_drop_0_2_24_19.json
# cnn_drop_0_3_24_19.json
# m_4_cnn_300_lr001_28.json
# values: [0.72177792 0.7335555  0.71866667 0.7106666 ]
# vali acc_values [0.7217779, 0.7335555, 0.7186667, 0.7106666]

# %%
''' 
############### CNN Dropout ################

'''
# define 
folder = 'mirror_cnn_params'
template_path = folder + '/drop/0_1/cnn_drop_0_1_0'

# folders of histories
subfolders = ['drop/1_0','drop/1_1','drop/0_3','drop/0_1','drop/0_2_24','drop/0_3_24','4_300_001_r1'] #'4_300_00025_r1','4_300_0001_r1'

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path, epoch_limit=80) #, epoch_limit=80

# graph settings  
labels = ['1;0','1;1','0;3','0;1','0;2-24','0;3-24','none']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.9, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.60, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.5, 1.01],  metric2='accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.2, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, window=[0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, window=[0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, window=[0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', window=[0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, window=[0, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors)
bar_plot(
    avgs, labels,'Average of 30 Trainings', 'max','traintime', colors)
# Out:
# cnn_drop_1_0_20.json
# cnn_drop_1_1_8.json
# cnn_drop_0_3_21.json
# cnn_drop_0_1_0.json
# cnn_drop_0_2_24_19.json
# cnn_drop_0_3_24_19.json
# m_4_cnn_300_lr001_28.json
# values: [0.67044443 0.67777783 0.72155553 0.72177792 0.7335555  0.71866667
#  0.7106666 ]
# vali acc_values [0.6704444, 0.6777778, 0.72155553, 0.7217779, 0.7335555, 0.7186667, 0.7106666]

# %%
''' 
############### CNN Learning Rate ################

'''
# define 
folder = 'mirror_cnn_params'
template_path = folder + '/212_fcn/m_fcn_212_0'

#folders of histories
subfolders = ['4_300_0025_r1','4_300_00125_r1','4_300_001_r1','4_300_00075_r1','4_300_00025_r1'] #'4_300_00025_r1','4_300_0001_r1'

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path, epoch_limit=60)

# graph settings  
labels = ['0,0025','0,00125','0,001','0,00075','0,00025']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.9, 1.5], epoch_window=[0, 60])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.5, 0.8], epoch_window=[0, 60])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.5, 1.01],  metric2='accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.2, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, window=[0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, window=[0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, window=[0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', window=[0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, window=[0, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors)
# Out:
# m_4_cnn_300_lr0025_16.json
# m_4_cnn_300_lr00125_16.json
# m_4_cnn_300_lr001_28.json
# m_4_cnn_300_lr00075_25.json
# m_4_cnn_300_lr00025_12.json
# values: [0.67177778 0.71133333 0.7106666  0.69311124 0.64599991]
# vali acc_values [0.6717778, 0.71133333, 0.7106666, 0.69311124, 0.6459999]

# %%
''' 
############### CNN LR Plateau ################

'''
# define 
folder = 'mirror_cnn_params'
template_path = folder + '/212_fcn/m_fcn_212_0'

# folders of histories
subfolders = ['4_300_001','4_300']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['300-4 RL','300-4']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.6, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 0.8])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 0.91], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.2, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, [0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors)
bar_plot(
    avgs, labels,'Average of 30 Trainings', 'max','traintime', colors, [0, 110])
# Out:
# m_4_cnn_300_lr001_7.json
# m_4_cnn_300_19.json
# values: [0.73066658 0.71777779]
# vali acc_values [0.7306666, 0.7177778]

# %%
''' 
############### CNN Layer ################

'''
# define 
folder = 'mirror_cnn_params'
template_path = folder + '/212_fcn/m_fcn_212_0'

# folders of histories
subfolders = ['4_175','5_175','4_212','5_212','4_250','5_250','4_300']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['175-4','175-5','212-4','212-5','250-4','250-5','300-4']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.7, 1.1])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.65, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 0.91], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.2, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, [0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0, 0.8])
# Out:
# m_4_cnn_175_10.json
# m_cnn_175_8.json
# m_4_cnn_212_18.json
# m_cnn_212_15.json
# m_4_cnn_250_10.json
# m_cnn_250_26.json
# m_4_cnn_300_19.json
# values: [0.74666667 0.75333333 0.75999999 0.75999999 0.75999999 0.75999999
#  0.79333335]
# values: [0.71311104 0.7064445  0.71244442 0.71222228 0.72155553 0.7093333
#  0.71777779]
# vali acc_values [0.71311104, 0.7064445, 0.7124444, 0.7122223, 0.72155553, 0.7093333, 0.7177778]

# %%
''' 
############### CNN Layer ################
'''
# define 
folder = 'mirror_cnn_params'
template_path = folder + '/250/m_cnn_250_0'

# folders of histories
subfolders = ['375','5_250','5_212','5_175']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings
labels = subfolders = ['375','250','212','175']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.75, 1])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.65, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'lower right','Average of 30 Trainings', colors, [0.5, 1], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.2, 1])
bar_plot(
    avgs, labels,'Maximum of 30 Trainings', 'max','val_accuracy', colors, [0.5, 0.8])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0.5, 0.8])
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors, [0.5, 0.8])
bar_plot(
    avgs, labels,'Maximum vom Run-Average', 'max','traintime', colors)
# Out:
# m_cnn_375_14.json
# m_cnn_250_26.json
# m_cnn_212_15.json
# m_cnn_175_8.json
# values: [0.70155555 0.7093333  0.71222228 0.7064445 ]
# vali acc_values [0.70155555, 0.7093333, 0.7122223, 0.7064445]

# %%
''' 
je 2 Runs mit und ohne mirror vom 9.8.
80 Epochen
'''
# define 
folder = 'mirror_3'
template_path = folder + '/no32/cnn_50t_2_0'

#folders of histories
subfolders = ['mirror32','no32','mirror48'] #'mirror48',mirror128

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = subfolders
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper right',
    'Average',colors, [0.9, 3])
plot_graph(
    'val_accuracy', avgs, labels, 'lower right',
    'Average',colors)
plot_graph(
    'accuracy', avgs, labels, 'upper left',
    'Average', colors)
bar_plot(
    avgs, labels,'Maximum vom Run-Average', 'max',
    'traintime', colors)
# Out:
# best: 1
# best: 0
# best: 0

# %%
''' 
without Mirror
############### CNN Params ################
je 30 Runsauf VM r3
80 Epochen
best are 75t, 62t, and 50t parameters in CNN with 5 Layers
'''
# define 
folder = 'cnn_params'
template_path = folder + '/10/cnn_10t_0'

#folders of histories
subfolders = ['1000','500','250','100','50','25']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = subfolders
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left',
    'Average of 30 Trainings', colors, [0.75, 1.25])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left',
    'Average of 30 Trainings', colors, [0.6, 0.91], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left',
    'Average of 30 Trainings', colors, [0.2, 0.91])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min',
    'val_loss', colors, [0, 1])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss',
    'val_accuracy', colors, [0, 1])
bar_plot(
    avgs, labels,'Maximum of 30 Trainings', 'max',
    'traintime', colors)
# Out:
# cnn_1000t_5.json
# cnn_500t_1.json
# cnn_100t_21.json
# cnn_100t_11.json
# cnn_50t_10.json
# cnn_25t_16.json
# values: [0.67225814 0.68236554 0.7062223  0.69244444 0.67955565 0.648     ]
