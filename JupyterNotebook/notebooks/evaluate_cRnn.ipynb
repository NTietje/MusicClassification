# %% [markdown]
# Erstellung der CNN-Darstellungen zu den Trainingsiterationen.
# Bei jedem Codeblock verweist der Titel auf den untersuchten Bereich.

# %%
from ipynb.fs.full.history_nb import *
from ipynb.fs.full.plot import *

# %% [markdown]
# Die ersten Bezeichnungen, die in der Ausgabe erscheinen wie "m_cRnn_100_lr00025_23.json", sind die besten Trainingsdurchläufe einer Variante.

# %%
''' 
############### CRNN dropout ################

'''
# define 
folder = 'mirror_cRnn_params'
template_path = folder + '/drop/1_1_0/cRnn_drop_1_0_0'

# folders of histories
subfolders = ['drop/0_2_0_24_b','drop/0_3_0_24_b','100_lr00025']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['0;2;0-24','0;3;0-24','none']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:cyan']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.9, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 1], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average', colors, [0.4, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, [0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
# Out:
# gpu3_cRnn_drop_best_100_2.json
# gpu3_cRnn_drop_best_3_100_23.json
# m_cRnn_100_lr00025_23.json
# values: [0.6784445  0.69466668 0.69066674]

# %%
''' 
############### CRNN dropout ################

'''
# define 
folder = 'mirror_cRnn_params'
template_path = folder + '/drop/1_1_0/cRnn_drop_1_0_0'

# folders of histories
subfolders = ['drop/1_1_0','drop/1_1_1','drop/0_0_1','drop/0_1_0','100_lr00025']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['1;1;0','1;1;1','0;0;1','0;1;0','none']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 'tab:cyan']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.9, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 1], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average', colors, [0.4, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, [0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
# Out:
# cRnn_drop_1_0_8.json
# cRnn_drop_1_1_19.json
# cRnn_drop_0_0_1_8.json
# cRnn_drop_0_1_0_12.json
# m_cRnn_100_lr00025_23.json
# values: [0.60311109 0.60866672 0.6673333  0.68366659 0.69066674]
# vali acc_values [0.6031111, 0.6086667, 0.6673333, 0.6836666, 0.69066674]

# %%
''' 
############### CRNN Learning Rate ################

'''
# define 
folder = 'mirror_cRnn_params'
template_path = folder + '/75/m_cRnn_75t_0'

# folders of histories
subfolders = ['100_lr001','100_lr00075','100_lr0005','100_lr00025','100_lr0001']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['0,001','0,00075','0,0005','0,00025','0,0001']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink'] 

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, window=[0.9, 1.1])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.63, 0.73])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 1], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average', colors, [0.4, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1.3])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, [0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
# Out:
# m_cRnn_100_lr001_10.json
# m_cRnn_100_lr00075_21.json
# m_cRnn_100_lr0005_26.json
# m_cRnn_100_lr00025_23.json
# m_cRnn_100_lr0001_26.json
# values: [0.69288886 0.68555552 0.68000001 0.69066674 0.68733335]
# vali acc_values [0.69288886, 0.6855555, 0.68, 0.69066674, 0.68733335]

# %%
''' 
############### CRNN 3 Conv Layer ################

'''
# define 
folder = 'mirror_cRnn_params'
template_path = folder + '/75/m_cRnn_75t_0'

# folders of histories
subfolders = ['150_3c','125','125_3c','100','100_3c']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['150-3','125-4','125-3','100-4','100-3']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink'] 

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.8, 1.1])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.65, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 1], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average', colors, [0.4, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1])
bar_plot(
    avgs, labels,'Test_loss', 'eval','eval_test_loss', colors, [0, 1.3])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
evaluate_bar_plot(avgs, labels, 'accuracy', [0, 1], figsize=(7, 1.5))
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
# Out:
# m_3_cRnn_150t_23.json
# m_cRnn_125t_13.json
# m_3_cRnn_125t_26.json
# m_cRnn_100t_9.json
# m_3_cRnn_100t_13.json
# values: [0.69044453 0.70844436 0.69222218 0.71644437 0.68155569]
# vali acc_values [0.6904445, 0.70844436, 0.6922222, 0.7164444, 0.6815557]

# %%
''' 
############### CRNN LSTM ################

'''
# define 
folder = 'mirror_cRnn_params'
template_path = folder + '/100_lstm/m_cRnn_lstm_100t_0'

# folders of histories
subfolders = ['100','100_lstm','125','125_lstm']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = ['100-GRU','100-LSTM','125-GRU','125-LSTM']
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper right','Average of 30 Trainings', colors, [0.8, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.6, 0.91], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average', colors, [0.4, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0.6, 1])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors, [0.5, 0.8])
# Out:
# m_cRnn_100t_9.json
# m_cRnn_lstm_100t_13.json
# m_cRnn_125t_13.json
# m_cRnn_lstm_125t_0.json
# values: [0.71644437 0.6684444  0.70844436 0.67199993]

# %%
''' 
############### CRNN Params Second ################
'''
# define 
folder = 'mirror_cRnn_params'
template_path = folder + '/75/m_cRnn_75t_0'

# folders of histories
subfolders = ['150','125','100','75']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = subfolders
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink'] 

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper right','Average of 30 Trainings', colors, [0.8, 1.2])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.6, 0.75])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.5, 1], 'accuracy')
plot_graph(
    'accuracy', avgs, labels, 'upper left','Average', colors, [0.4, 1])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min','val_loss', colors, [0, 1])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss','val_accuracy', colors, [0, 1])
bar_plot(
    avgs, labels,'Test_acc', 'eval','eval_test_acc', colors, [0.5, 0.8])
bar_plot(
    avgs, labels,'Val_acc', 'eval','eval_val_acc', colors, [0.5, 0.8])
bar_plot(
    avgs, labels,'Maximum of 30 Trainings', 'max','traintime', colors)
# Out:
# m_cRnn_150t_11.json
# m_cRnn_125t_13.json
# m_cRnn_100t_9.json
# m_cRnn_75t_29.json
# values: [0.70844448 0.70844436 0.71644437 0.68200004]

# %%
''' 
without Mirror
############### CRNN Params ################
'''
# define 
folder = 'cRnn_params'
template_path = folder + '/100/cRnn_100t_0'

# folders of histories
subfolders = ['500','250','100','50','25']

# get best and avgs
folder_hist_list = get_histories_of_subfolders(subfolders, folder)
best, avgs = get_best_and_avgs(folder_hist_list, template_path)

# graph settings  
labels = subfolders
colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink']

############# avg ###############
plot_graph(
    'val_loss', avgs, labels, 'upper right',
    'Average of 30 Trainings', colors, [0.8, 1.4])
plot_graph(
    'val_accuracy', avgs, labels, 'upper left','Average of 30 Trainings', colors, [0.6, 0.91], 'accuracy')
bar_plot(
    avgs, labels,'Maximum of 30 Trainings', 'max',
    'val_accuracy', colors, [0, 0.91])
bar_plot(
    avgs, labels,'Minimum of 30 Trainings', 'min',
    'val_loss', colors, [0, 1.1])
bar_plot_loss_min(
    avgs, labels,'Val_Accuracy at Minimum Val_Loss',
    'val_accuracy', colors, [0, 1])
bar_plot(
    avgs, labels,'Maximum vom Run-Average', 'max',
    'traintime', colors)
# Out:
# cRnn_500t_11.json
# cRnn_250t_15.json
# cRnn_100t_21.json
# cRnn_50t_8.json
# cRnn_25t_27.json
# values: [0.66311115 0.67133331 0.71533334 0.7077778  0.67577779]
